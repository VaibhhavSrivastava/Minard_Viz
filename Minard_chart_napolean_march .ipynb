# %%
from altair.vegalite.v4.schema import Tooltip
from altair.vegalite.v4.schema.channels import X
import pandas as pd
import altair as alt
import numpy as np



class Minard:
    def __init__(self,csv_file):
        self.csv_file = csv_file
        self.minard_dataset = pd.read_csv(self.csv_file)

    def split_into_three_ds(self):
        self.data_1 = self.minard_dataset[self.minard_dataset.columns[[0,1,2]]]
        self.data_1['LONC'] = self.data_1['LONC'].fillna(' ')
        self.data_1['LATC'] = self.data_1['LATC'].fillna(' ')
        self.data_1['CITY'] = self.data_1['CITY'].fillna(' ')

        self.data_2 = self.minard_dataset[self.minard_dataset.columns[[3,4,5,6,7]]]
        self.data_2 = self.data_2.dropna(subset=['MON'])
        self.data_2['LONT'] = self.data_2['LONT'].fillna(' ')
        self.data_2['TEMP'] = self.data_2['TEMP'].fillna(' ')
        self.data_2['DAYS'] = self.data_2['DAYS'].fillna(' ')
        self.data_2['MON'] = self.data_2['MON'].fillna(' ')
        self.data_2['DAY'] = self.data_2['DAY'].astype(str)
        self.data_2['DAY'] = self.data_2['DAY'].str.strip('.0')
        self.data_2['DATE'] = self.data_2['DAY'] + " " + self.data_2['MON']
        

        self.data_3 = self.minard_dataset[self.minard_dataset.columns[[8,9,10,11,12]]]
        self.surv_data = self.return_uniq_survivors()
        transform_list = self.transform_surv_cols(self.surv_data["SURV"])
        self.surv_data["SURV"] = transform_list
    def return_city(self,city):
      return (self.data_1.loc[self.data_1['CITY'] == city])
    
    def attack_city(self,num):
      return (self.surv_data.loc[self.surv_data['SURV']==num])
    

    def transform_surv_cols(self,surv):
      list_ = []
      for i in surv:
        rem = str(int(i/1000))+'K'
        list_.append(rem)
      return list_

    def plot_for_troops(self):
      troops_data = self.data_3
      dir_vals = ['A','R']
      dir_colors = ["#808000","black"]
      div_values = ['1','2','3']
      div_colors = ['#994C00','#994C00','#994C00']
      city_1 = self.return_city("Kowno")
      city_2 = self.return_city("Wilna")
      city_3 = self.return_city("Smorgoni")
      city_4 = self.return_city("Molodexno")
      city_5 = self.return_city("Gloubokoe")
      city_6 = self.return_city("Minsk")
      city_7 = self.return_city("Studienska")
      city_8 = self.return_city("Polotzk")
      city_9 = self.return_city("Bobr")
      city_10 = self.return_city("Witebsk")
      city_11 = self.return_city("Orscha")
      city_12 = self.return_city("Mohilow")
      city_13 = self.return_city("Smolensk")
      city_14 = self.return_city("Dorogobouge")
      city_15 = self.return_city("Wixma")
      city_16 = self.return_city("Chjat")
      city_17 = self.return_city("Mojaisk")
      city_18 = self.return_city("Moscou")
      city_19 = self.return_city("Tarantino")
      city_20 = self.return_city("Malo-jarosewli")
      plot_troops = alt.Chart(troops_data).mark_trail(opacity = 0.6).encode(
          longitude='LONP:Q',
          latitude='LATP:Q',
          size=alt.Size(
            'SURV',
            scale=alt.Scale(range=[2, 30]),
            legend=None
        ),
          detail = 'DIV',
          color=alt.Color('DIV', scale=alt.Scale(domain=div_values,range=div_colors),legend=None),
          tooltip=['LONP','LATP','SURV','DIR']
      )
      plot_troops_dir = alt.Chart(troops_data).mark_trail(opacity = 0.6).encode(
          longitude='LONP:Q',
          latitude='LATP:Q',
          size=alt.Size(
            'SURV',
            scale=alt.Scale(range=[2, 30]),
            legend=None
        ),
          detail = 'DIV',
          color=alt.Color('DIR', scale=alt.Scale(domain=dir_vals,range=dir_colors)),
          tooltip=['LONP','LATP','SURV','DIR']
      )
      plot_city_1 = alt.Chart(city_1).mark_text(
          dx=90,
          dy=200,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
          angle=20
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_2 = alt.Chart(city_2).mark_text(
          dx=120,
          dy=200,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
          angle=20
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_3 = alt.Chart(city_3).mark_text(
          dx=130,
          dy=270,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_4 = alt.Chart(city_4).mark_text(
          dx=150,
          dy=290,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_5 = alt.Chart(city_5).mark_text(
          dx=200,
          dy=180,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_6 = alt.Chart(city_6).mark_text(
          dx=220,
          dy=320,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_7 = alt.Chart(city_7).mark_text(
          dx=260,
          dy=310,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_8 = alt.Chart(city_8).mark_text(
          dx=280,
          dy=150,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_9 = alt.Chart(city_9).mark_text(
          dx=310,
          dy=300,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_10 = alt.Chart(city_10).mark_text(
          dx=380,
          dy=190,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_11 = alt.Chart(city_11).mark_text(
          dx=410,
          dy=260,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_12 = alt.Chart(city_12).mark_text(
          dx=410,
          dy=320,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_13 = alt.Chart(city_13).mark_text(
          dx=470,
          dy=240,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_14 = alt.Chart(city_14).mark_text(
          dx=530,
          dy=215,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_15 = alt.Chart(city_15).mark_text(
          dx=600,
          dy=225,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_16 = alt.Chart(city_16).mark_text(
          dx=630,
          dy=165,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_17 = alt.Chart(city_17).mark_text(
          dx=710,
          dy=180,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_18 = alt.Chart(city_18).mark_text(
          dx=790,
          dy=120,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_19 = alt.Chart(city_19).mark_text(
          dx=830,
          dy=160,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      plot_city_20 = alt.Chart(city_20).mark_text(
          dx=820,
          dy=200,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'CITY'
      )
      
      plot_surv_data_a = self.plot_surv_chart_a()   
      plot_surv_data_b = self.plot_surv_chart_b()
      plot_surv_data_c = self.plot_surv_chart_c()
      plot_surv_data_d = self.plot_surv_chart_d()
      plot_surv_data_e = self.plot_surv_chart_e()
      plot_surv_data_f = self.plot_surv_chart_f()
      plot_surv_data_g = self.plot_surv_chart_g()
      plot_surv_data_h = self.plot_surv_chart_h()
      plot_surv_data_i = self.plot_surv_chart_i()
      plot_surv_data_j = self.plot_surv_chart_j()
      plot_surv_data_k = self.plot_surv_chart_k()
      plot_surv_data_l = self.plot_surv_chart_l()
      plot_surv_data_m = self.plot_surv_chart_m()
      plot_surv_data_n = self.plot_surv_chart_n()
      plot_surv_data_o = self.plot_surv_chart_o()
      plot_surv_data_p = self.plot_surv_chart_p()




      return plot_troops + plot_troops_dir+ plot_city_1+plot_city_2+ plot_city_3 + plot_city_4 + plot_city_5 + plot_city_6 + plot_city_7 + plot_city_8 + plot_city_9 + plot_city_10 + plot_city_11 + plot_city_12 + plot_city_13 + plot_city_14 + plot_city_15 + plot_city_16 + plot_city_17 + plot_city_18 + plot_city_19 + plot_city_20 + plot_surv_data_a + plot_surv_data_b + plot_surv_data_c + plot_surv_data_d + plot_surv_data_e + plot_surv_data_f + plot_surv_data_g + plot_surv_data_h + plot_surv_data_i + plot_surv_data_j + plot_surv_data_k + plot_surv_data_l + plot_surv_data_m + plot_surv_data_n + plot_surv_data_o + plot_surv_data_p
    

    def return_uniq_survivors(self):
      return self.data_3.drop_duplicates(subset = "SURV")

    def plot_temperature_map(self):
      temp_data = self.data_2.loc[self.data_2['TEMP'] != ' ']
      temp_data = temp_data.dropna()
      temp_map = alt.Chart(temp_data).mark_line(point=alt.OverlayMarkDef(color="red")).encode(
          x=alt.X('LONT:Q', scale = alt.Scale(domain=[24,38]),axis=alt.Axis(title='Longitude',grid=True)),
          y=alt.Y('TEMP:Q', scale = alt.Scale(domain=[-40,10]),axis=alt.Axis(title='Temperature',orient='right',grid=False)),
          tooltip = ['LONT','TEMP','DATE']
      ).properties(
          width=820,
          height=430
      ) + alt.Chart(temp_data).mark_text(
        font='Arial',
        dx = 8,
        dy = 15,
    ).encode(
        x=alt.X('LONT:Q', scale = alt.Scale(domain=[24,38]),axis=alt.Axis(title='Longitude',grid=True)),
        y=alt.Y('TEMP:Q', scale = alt.Scale(domain=[-40,10]),axis=alt.Axis(title='Temperature',orient='right',grid=False)),
        text='DATE',
    )
      return temp_map

    def scale_for_final_map(self):
        troop_data = self.data_3
        axis_map = alt.Chart(troop_data).mark_text().encode(
        x = alt.X(
        'LONP:Q',
        scale=alt.Scale(domain=[24, 38]),
        axis=alt.Axis(title="Longitude", grid=True)
        ),

        y = alt.Y(
        'LATP:Q',
        scale=alt.Scale(domain=[50,60]),
        axis=alt.Axis(title="Latitude", grid=False)
        )
        ).properties(
            width=820,
            height=430,
            title="Minard's Map Of Napoleans Army March to Russia"
        )

        return axis_map
    
    def plot_surv_chart_a(self):
      surv_a = self.attack_city("340K")
      plot_surv_a = alt.Chart(surv_a).mark_text(
          dx=70,
          dy=23,
          fontSize=9,
          color='#404040',
          fontStyle='Bold'
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_a
    
    def plot_surv_chart_b(self):
      surv_b = self.attack_city("60K")
      plot_surv_b = alt.Chart(surv_b).mark_text(
          dx=135,
          dy=0,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_b
    
    def plot_surv_chart_c(self):
      surv_c = self.attack_city("30K")
      plot_surv_c = alt.Chart(surv_c).mark_text(
          dx=20,
          dy=0,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_c
    
    def plot_surv_chart_d(self):
      surv_d = self.attack_city("300K")
      plot_surv_d = alt.Chart(surv_d).mark_text(
          dx=20,
          dy=0,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_d

    def plot_surv_chart_e(self):
      surv_e = self.attack_city("240K")
      plot_surv_e = alt.Chart(surv_e).mark_text(
          dx=10,
          dy=-8,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_e
    
    def plot_surv_chart_f(self):
      surv_f = self.attack_city("175K")
      plot_surv_f = alt.Chart(surv_f).mark_text(
          dx=10,
          dy=-15,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_f
    
    def plot_surv_chart_g(self):
      surv_g = self.attack_city("145K")
      plot_surv_g = alt.Chart(surv_g).mark_text(
          dx=0,
          dy=-25,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_g

    def plot_surv_chart_h(self):
      surv_h = self.attack_city("127K")
      plot_surv_h = alt.Chart(surv_h).mark_text(
          dx=0,
          dy=-16,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_h
    
    def plot_surv_chart_i(self):
      surv_i = self.attack_city("100K")
      plot_surv_i = alt.Chart(surv_i).mark_text(
          dx=140,
          dy=-60,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_i
    
    def plot_surv_chart_j(self):
      surv_j = self.attack_city("97K")
      plot_surv_j = alt.Chart(surv_j).mark_text(
          dx=0,
          dy=15,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv_j
    
    def plot_surv_chart_k(self):
      surv = self.attack_city("55K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=0,
          dy=15,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv

    def plot_surv_chart_l(self):
      surv = self.attack_city("37K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=0,
          dy=15,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv

    def plot_surv_chart_m(self):
      surv = self.attack_city("20K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=0,
          dy=10,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv

    def plot_surv_chart_n(self):
      surv = self.attack_city("30K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=40,
          dy=150,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv

    def plot_surv_chart_o(self):
      surv = self.attack_city("8K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=10,
          dy=10,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv
    
    def plot_surv_chart_p(self):
      surv = self.attack_city("4K")
      plot_surv = alt.Chart(surv).mark_text(
          dx=0,
          dy=10,
          fontSize=9,
          color='#404040',
          fontStyle='Bold',
      ).encode(
          longitude="LONP:Q",
          latitude="LATP:Q",
          text = 'SURV'
      )
      return plot_surv


def main():
  m = Minard("minard-data.csv")
  m.split_into_three_ds()
  m.return_uniq_survivors()
  g_map = m.scale_for_final_map()
  temp_map = m.plot_temperature_map()
  combo_map = alt.vconcat((g_map +m.plot_for_troops()), temp_map, center=True).configure(background='#FFCC99')
  combo_map.save('minard_chart.html')
if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
